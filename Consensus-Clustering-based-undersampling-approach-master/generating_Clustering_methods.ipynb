# %% [markdown]
# **k-means Clustering:**

# %%
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
# class_majority_df=pd.read_csv('DataSets/car_evaluation_majority.csv')
# class_majority_df=pd.read_csv('DataSets/yeast5_majority.csv')
class_majority_df=pd.read_csv('DataSets/pima_majority.csv')

# %%
import pandas as pd
columns=['Kmeans','Kmeans++','Minibatch']
clustering_result=pd.DataFrame(columns=columns)

# %%
sse={}
for k in range(2,10):
  kmeans=KMeans(n_clusters=k,init='random',max_iter=500).fit(class_majority_df)
  sse[k]=kmeans.inertia_
plt.plot(list(sse.keys()),list(sse.values()),'bx-')
plt.xlabel("Number of Cluster")
plt.ylabel("SSE")
plt.savefig("elbow_method.png")
# Out:
# c:\Users\CVR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\CVR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\CVR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\CVR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\CVR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\CVR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\CVR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\CVR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\CVR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\CVR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\CVR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\CVR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\CVR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\CVR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\CVR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\CVR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
num_of_clusters=7 # since it is the elbow point

# %%
kmeans=KMeans(n_clusters=7,init='random',max_iter=500).fit(class_majority_df)
clustering_result['Kmeans']=kmeans.labels_
# Out:
# c:\Users\CVR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\CVR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
partition1 = class_majority_df
partition1=partition1.reset_index(drop=True)
partition1['cluster_label'] = clustering_result['Kmeans']
partition1 #with cluster labels
# Out:
#      Unnamed: 0  Preg   Plas   Pres  Skin   Insu  Mass   Pedi   Age  result  \
# 0           656   5.0   88.0   66.0  21.0   23.0  24.4  0.342  30.0       0
# 1           400   0.0  129.0   80.0   0.0    0.0  31.2  0.703  29.0       0
# 2           529   4.0  189.0  110.0  31.0    0.0  28.5  0.680  37.0       0
# 3           474   6.0   96.0    0.0   0.0    0.0  23.7  0.190  28.0       0
# 4            25   8.0   85.0   55.0  20.0    0.0  24.4  0.136  42.0       0
# ..          ...   ...    ...    ...   ...    ...   ...    ...   ...     ...
# 401         485   1.0  126.0   56.0  29.0  152.0  28.7  0.801  21.0       0
# 402         611   5.0  117.0   92.0   0.0    0.0  34.1  0.337  38.0       0
# 403         697   4.0  112.0   78.0  40.0    0.0  39.4  0.236  38.0       0
# 404         714   3.0   78.0   70.0   0.0    0.0  32.5  0.270  39.0       0
# 405         354   6.0  144.0   72.0  27.0  228.0  33.9  0.255  40.0       0
#
#      cluster_label
# 0                6
# 1                3
# 2                3
# 3                3
# 4                0
# ..             ...
# 401              4
# 402              6
# 403              6
# 404              6
# 405              5
#
# [406 rows x 11 columns]

# %% [markdown]
# **KMeans++ Clustering:**

# %%
kmeans=KMeans(n_clusters=num_of_clusters,init='k-means++',max_iter=500).fit(class_majority_df)
clustering_result['Kmeans++']=kmeans.labels_
# Out:
# c:\Users\CVR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\CVR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(

# %%
partition2 = class_majority_df
partition2=partition2.reset_index(drop=True)
partition2['cluster_label'] = clustering_result['Kmeans++']
partition2 #with cluster labels
# Out:
#      Unnamed: 0  Preg   Plas   Pres  Skin   Insu  Mass   Pedi   Age  result  \
# 0           656   5.0   88.0   66.0  21.0   23.0  24.4  0.342  30.0       0
# 1           400   0.0  129.0   80.0   0.0    0.0  31.2  0.703  29.0       0
# 2           529   4.0  189.0  110.0  31.0    0.0  28.5  0.680  37.0       0
# 3           474   6.0   96.0    0.0   0.0    0.0  23.7  0.190  28.0       0
# 4            25   8.0   85.0   55.0  20.0    0.0  24.4  0.136  42.0       0
# ..          ...   ...    ...    ...   ...    ...   ...    ...   ...     ...
# 401         485   1.0  126.0   56.0  29.0  152.0  28.7  0.801  21.0       0
# 402         611   5.0  117.0   92.0   0.0    0.0  34.1  0.337  38.0       0
# 403         697   4.0  112.0   78.0  40.0    0.0  39.4  0.236  38.0       0
# 404         714   3.0   78.0   70.0   0.0    0.0  32.5  0.270  39.0       0
# 405         354   6.0  144.0   72.0  27.0  228.0  33.9  0.255  40.0       0
#
#      cluster_label
# 0                2
# 1                5
# 2                5
# 3                5
# 4                4
# ..             ...
# 401              0
# 402              2
# 403              2
# 404              2
# 405              1
#
# [406 rows x 11 columns]

# %% [markdown]
# **K-Modes Clustering:**

# %%
# %pip install kmodes
# Out:
# Requirement already satisfied: kmodes in c:\users\cvr\anaconda3\lib\site-packages (0.12.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.10.4 in c:\users\cvr\anaconda3\lib\site-packages (from kmodes) (1.26.4)
# Requirement already satisfied: scikit-learn>=0.22.0 in c:\users\cvr\anaconda3\lib\site-packages (from kmodes) (1.2.2)
# Requirement already satisfied: scipy>=0.13.3 in c:\users\cvr\anaconda3\lib\site-packages (from kmodes) (1.11.4)
# Requirement already satisfied: joblib>=0.11 in c:\users\cvr\anaconda3\lib\site-packages (from kmodes) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\cvr\anaconda3\lib\site-packages (from scikit-learn>=0.22.0->kmodes) (2.2.0)

# %%
from kmodes.kmodes import KModes


km = KModes(n_clusters=num_of_clusters, init='Huang', n_init=5, verbose=1)

clusters = km.fit_predict(class_majority_df)

df_0_centroids=km.cluster_centroids_
clusters
# Out:
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 1, iteration: 1/100, moves: 54, cost: 2857.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 2, iteration: 1/100, moves: 88, cost: 2847.0
# Run 2, iteration: 2/100, moves: 12, cost: 2847.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 3, iteration: 1/100, moves: 90, cost: 2840.0
# Run 3, iteration: 2/100, moves: 33, cost: 2830.0
# Run 3, iteration: 3/100, moves: 5, cost: 2830.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 4, iteration: 1/100, moves: 51, cost: 2835.0
# Run 4, iteration: 2/100, moves: 8, cost: 2835.0
# Init: initializing centroids
# Init: initializing clusters
# Starting iterations...
# Run 5, iteration: 1/100, moves: 74, cost: 2871.0
# Run 5, iteration: 2/100, moves: 2, cost: 2871.0
# Best run was number 3
# array([0, 1, 0, 0, 6, 5, 0, 6, 0, 4, 0, 2, 2, 1, 0, 1, 1, 3, 5, 4, 0, 0,
#        1, 5, 0, 0, 1, 4, 1, 0, 5, 3, 0, 1, 1, 3, 0, 1, 0, 3, 1, 4, 1, 2,
#        0, 1, 0, 0, 2, 2, 0, 2, 0, 2, 5, 6, 0, 3, 1, 4, 1, 0, 3, 3, 5, 3,
#        0, 2, 4, 3, 6, 2, 0, 1, 3, 1, 0, 3, 0, 0, 6, 0, 5, 1, 5, 2, 2, 0,
#        3, 0, 0, 3, 0, 6, 0, 3, 1, 6, 1, 6, 0, 0, 5, 0, 3, 5, 0, 2, 1, 4,
#        2, 0, 3, 0, 1, 3, 2, 2, 0, 1, 2, 1, 0, 1, 4, 5, 6, 2, 0, 0, 5, 3,
#        1, 1, 1, 4, 1, 5, 1, 3, 2, 4, 0, 0, 2, 1, 0, 4, 6, 0, 3, 1, 1, 6,
#        1, 2, 0, 0, 0, 3, 6, 0, 0, 0, 2, 3, 0, 6, 5, 2, 2, 0, 2, 3, 0, 6,
#        0, 2, 2, 0, 0, 3, 1, 0, 0, 2, 0, 5, 0, 0, 3, 2, 0, 1, 1, 0, 0, 4,
#        4, 0, 4, 5, 0, 6, 0, 0, 5, 0, 0, 6, 0, 2, 0, 2, 3, 0, 2, 0, 0, 0,
#        5, 1, 3, 3, 4, 0, 0, 3, 6, 2, 0, 3, 5, 0, 0, 0, 5, 0, 0, 2, 5, 5,
#        0, 6, 0, 1, 2, 1, 1, 4, 1, 2, 0, 0, 0, 1, 2, 0, 0, 0, 3, 1, 0, 3,
#        4, 1, 1, 0, 3, 0, 1, 5, 0, 4, 0, 0, 0, 1, 0, 0, 3, 0, 3, 1, 3, 3,
#        4, 5, 1, 3, 2, 1, 3, 3, 5, 0, 2, 0, 0, 3, 4, 2, 0, 0, 3, 2, 1, 0,
#        0, 2, 0, 1, 0, 1, 0, 4, 5, 3, 3, 0, 5, 5, 1, 0, 3, 1, 1, 4, 0, 3,
#        5, 1, 0, 3, 0, 0, 1, 3, 0, 0, 1, 2, 1, 6, 6, 0, 0, 5, 0, 0, 2, 0,
#        0, 0, 2, 3, 3, 0, 2, 1, 3, 3, 2, 5, 1, 6, 2, 1, 0, 0, 4, 0, 0, 0,
#        0, 0, 0, 2, 1, 0, 1, 0, 6, 2, 2, 0, 3, 2, 0, 0, 4, 1, 4, 1, 2, 1,
#        1, 6, 5, 0, 6, 3, 0, 0, 0, 0], dtype=uint16)

# %%
partition3 = class_majority_df
partition3=partition3.reset_index(drop=True)
partition3['cluster_label'] = clusters
partition3 #with cluster labels
# Out:
#      Unnamed: 0  Preg   Plas   Pres  Skin   Insu  Mass   Pedi   Age  result  \
# 0           656   5.0   88.0   66.0  21.0   23.0  24.4  0.342  30.0       0
# 1           400   0.0  129.0   80.0   0.0    0.0  31.2  0.703  29.0       0
# 2           529   4.0  189.0  110.0  31.0    0.0  28.5  0.680  37.0       0
# 3           474   6.0   96.0    0.0   0.0    0.0  23.7  0.190  28.0       0
# 4            25   8.0   85.0   55.0  20.0    0.0  24.4  0.136  42.0       0
# ..          ...   ...    ...    ...   ...    ...   ...    ...   ...     ...
# 401         485   1.0  126.0   56.0  29.0  152.0  28.7  0.801  21.0       0
# 402         611   5.0  117.0   92.0   0.0    0.0  34.1  0.337  38.0       0
# 403         697   4.0  112.0   78.0  40.0    0.0  39.4  0.236  38.0       0
# 404         714   3.0   78.0   70.0   0.0    0.0  32.5  0.270  39.0       0
# 405         354   6.0  144.0   72.0  27.0  228.0  33.9  0.255  40.0       0
#
#      cluster_label
# 0                0
# 1                1
# 2                0
# 3                0
# 4                6
# ..             ...
# 401              3
# 402              0
# 403              0
# 404              0
# 405              0
#
# [406 rows x 11 columns]

# %% [markdown]
# **MINIBATCH KMEANS CLUSTERING:**

# %%
from sklearn.cluster import MiniBatchKMeans
mbk = MiniBatchKMeans(init='k-means++', n_clusters=num_of_clusters, batch_size=40, n_init=10, max_no_improvement=10, verbose=0)
mbk.fit(class_majority_df)
clustering_result['Minibatch']=mbk.labels_
# Out:
# c:\Users\CVR\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1902: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 1024 or by setting the environment variable OMP_NUM_THREADS=1
#   warnings.warn(

# %%
clustering_result['Minibatch'].values
# Out:
# array([1, 3, 3, 3, 5, 1, 4, 3, 1, 0, 4, 3, 0, 5, 3, 1, 0, 6, 6, 0, 5, 0,
#        3, 1, 5, 5, 0, 0, 1, 5, 5, 1, 3, 0, 3, 1, 0, 0, 5, 1, 6, 1, 5, 5,
#        1, 5, 6, 4, 5, 3, 6, 6, 6, 3, 3, 1, 4, 6, 5, 0, 6, 1, 4, 4, 0, 6,
#        2, 0, 0, 4, 6, 3, 3, 2, 0, 0, 5, 4, 3, 5, 5, 5, 2, 0, 0, 3, 1, 3,
#        3, 3, 0, 2, 5, 4, 0, 4, 0, 0, 4, 0, 3, 3, 0, 4, 5, 5, 3, 1, 1, 5,
#        0, 3, 1, 0, 4, 0, 6, 4, 0, 3, 5, 3, 5, 6, 5, 5, 1, 0, 3, 3, 1, 0,
#        6, 5, 0, 6, 4, 6, 5, 3, 0, 6, 4, 4, 6, 4, 0, 1, 0, 1, 5, 3, 0, 0,
#        0, 5, 0, 3, 4, 0, 5, 3, 1, 1, 3, 1, 5, 4, 6, 0, 0, 5, 4, 6, 6, 1,
#        5, 0, 1, 1, 0, 0, 3, 5, 5, 6, 5, 1, 4, 5, 0, 0, 3, 3, 5, 5, 1, 0,
#        0, 0, 3, 0, 2, 0, 5, 1, 5, 1, 3, 6, 0, 5, 5, 3, 6, 6, 6, 0, 2, 6,
#        0, 1, 5, 3, 0, 5, 5, 3, 3, 0, 1, 4, 4, 4, 0, 3, 5, 3, 0, 3, 4, 3,
#        4, 1, 3, 0, 6, 3, 5, 3, 4, 2, 0, 5, 2, 5, 5, 0, 0, 1, 5, 5, 5, 5,
#        5, 6, 6, 0, 5, 5, 0, 1, 6, 6, 5, 0, 0, 5, 6, 5, 4, 5, 2, 1, 6, 0,
#        0, 3, 1, 6, 0, 2, 1, 6, 3, 6, 0, 4, 0, 2, 3, 5, 3, 3, 5, 3, 1, 1,
#        3, 6, 5, 5, 5, 3, 0, 5, 5, 5, 1, 0, 0, 3, 3, 3, 3, 6, 1, 5, 3, 6,
#        5, 2, 0, 5, 3, 0, 4, 5, 3, 6, 3, 6, 0, 0, 3, 0, 4, 2, 1, 1, 1, 1,
#        5, 0, 4, 1, 3, 1, 4, 0, 2, 6, 0, 5, 0, 6, 0, 4, 6, 3, 4, 0, 3, 5,
#        5, 4, 2, 1, 0, 3, 2, 6, 0, 1, 0, 0, 1, 5, 3, 2, 3, 3, 0, 2, 0, 5,
#        2, 2, 1, 0, 5, 4, 1, 6, 6, 4])

# %%
partition4 = class_majority_df
partition4=partition4.reset_index(drop=True)
partition4['cluster_label'] = clustering_result['Minibatch']
partition4
# Out:
#      Unnamed: 0  Preg   Plas   Pres  Skin   Insu  Mass   Pedi   Age  result  \
# 0           656   5.0   88.0   66.0  21.0   23.0  24.4  0.342  30.0       0
# 1           400   0.0  129.0   80.0   0.0    0.0  31.2  0.703  29.0       0
# 2           529   4.0  189.0  110.0  31.0    0.0  28.5  0.680  37.0       0
# 3           474   6.0   96.0    0.0   0.0    0.0  23.7  0.190  28.0       0
# 4            25   8.0   85.0   55.0  20.0    0.0  24.4  0.136  42.0       0
# ..          ...   ...    ...    ...   ...    ...   ...    ...   ...     ...
# 401         485   1.0  126.0   56.0  29.0  152.0  28.7  0.801  21.0       0
# 402         611   5.0  117.0   92.0   0.0    0.0  34.1  0.337  38.0       0
# 403         697   4.0  112.0   78.0  40.0    0.0  39.4  0.236  38.0       0
# 404         714   3.0   78.0   70.0   0.0    0.0  32.5  0.270  39.0       0
# 405         354   6.0  144.0   72.0  27.0  228.0  33.9  0.255  40.0       0
#
#      cluster_label
# 0                1
# 1                3
# 2                3
# 3                3
# 4                5
# ..             ...
# 401              4
# 402              1
# 403              6
# 404              6
# 405              4
#
# [406 rows x 11 columns]

# %% [markdown]
# **Fuzzy K-Means Clustering**

# %%
# %pip install fuzzy-c-means
import numpy as np
from fcmeans import FCM
# Out:
# Requirement already satisfied: fuzzy-c-means in c:\users\cvr\anaconda3\lib\site-packages (1.7.2)
# Requirement already satisfied: joblib<2.0.0,>=1.2.0 in c:\users\cvr\anaconda3\lib\site-packages (from fuzzy-c-means) (1.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.21.1 in c:\users\cvr\anaconda3\lib\site-packages (from fuzzy-c-means) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.6.4 in c:\users\cvr\anaconda3\lib\site-packages (from fuzzy-c-means) (2.6.4)
# Requirement already satisfied: tabulate<0.9.0,>=0.8.9 in c:\users\cvr\anaconda3\lib\site-packages (from fuzzy-c-means) (0.8.10)
# Requirement already satisfied: tqdm<5.0.0,>=4.64.1 in c:\users\cvr\anaconda3\lib\site-packages (from fuzzy-c-means) (4.65.0)
# Requirement already satisfied: typer<0.10.0,>=0.9.0 in c:\users\cvr\anaconda3\lib\site-packages (from fuzzy-c-means) (0.9.4)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\cvr\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.6.4->fuzzy-c-means) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\cvr\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.6.4->fuzzy-c-means) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\cvr\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.6.4->fuzzy-c-means) (4.9.0)
# Requirement already satisfied: colorama in c:\users\cvr\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.64.1->fuzzy-c-means) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\cvr\anaconda3\lib\site-packages (from typer<0.10.0,>=0.9.0->fuzzy-c-means) (8.1.7)
# Note: you may need to restart the kernel to use updated packages.

# %%
fcm = FCM(n_clusters=num_of_clusters)
fcm.fit(class_majority_df.values)
# outputs
fcm_centers = fcm.centers
fcm_labels = fcm.predict(class_majority_df.values)
fcm_labels
# Out:
# array([4, 3, 6, 3, 2, 4, 1, 3, 6, 5, 1, 3, 5, 2, 3, 4, 0, 4, 4, 3, 2, 3,
#        1, 6, 2, 2, 5, 0, 4, 5, 2, 4, 6, 5, 3, 6, 0, 0, 5, 4, 4, 4, 2, 2,
#        6, 5, 4, 1, 2, 6, 4, 4, 4, 3, 3, 4, 1, 4, 2, 5, 4, 6, 1, 1, 5, 4,
#        0, 3, 0, 1, 4, 3, 3, 0, 0, 0, 5, 1, 6, 2, 5, 2, 0, 5, 5, 3, 6, 3,
#        3, 3, 5, 0, 2, 1, 0, 1, 0, 5, 1, 5, 3, 3, 5, 1, 2, 2, 3, 6, 6, 2,
#        5, 3, 6, 5, 1, 5, 4, 1, 0, 3, 2, 3, 5, 4, 2, 2, 6, 5, 3, 6, 6, 0,
#        4, 2, 5, 4, 0, 4, 2, 3, 5, 4, 1, 1, 4, 1, 3, 6, 3, 6, 2, 3, 0, 5,
#        3, 2, 3, 3, 1, 0, 2, 3, 6, 6, 3, 4, 5, 1, 4, 0, 3, 2, 1, 4, 4, 6,
#        2, 5, 6, 6, 5, 5, 3, 2, 2, 4, 2, 6, 1, 2, 0, 3, 1, 6, 5, 2, 6, 3,
#        5, 5, 3, 0, 0, 5, 2, 6, 2, 6, 3, 4, 3, 2, 2, 6, 4, 4, 4, 5, 0, 4,
#        5, 6, 5, 6, 0, 2, 2, 3, 1, 5, 6, 1, 1, 1, 0, 6, 2, 3, 5, 6, 1, 6,
#        1, 6, 3, 3, 4, 3, 2, 3, 0, 2, 5, 2, 2, 2, 2, 3, 5, 6, 2, 2, 2, 2,
#        5, 4, 4, 5, 2, 2, 0, 4, 4, 4, 2, 5, 5, 2, 4, 2, 1, 2, 2, 6, 4, 3,
#        5, 6, 1, 4, 0, 0, 6, 4, 6, 4, 5, 1, 5, 0, 3, 2, 6, 6, 2, 3, 1, 4,
#        0, 4, 2, 2, 2, 3, 0, 5, 2, 2, 1, 5, 3, 3, 6, 6, 6, 4, 4, 2, 3, 4,
#        2, 0, 5, 2, 6, 5, 1, 2, 3, 4, 3, 4, 3, 0, 3, 5, 1, 0, 4, 6, 6, 6,
#        2, 5, 1, 6, 3, 4, 1, 0, 0, 4, 5, 5, 5, 4, 3, 1, 4, 3, 1, 5, 6, 2,
#        2, 0, 0, 6, 5, 3, 0, 4, 3, 6, 3, 5, 6, 2, 3, 2, 6, 3, 3, 2, 5, 2,
#        0, 0, 6, 0, 5, 1, 6, 4, 4, 0], dtype=int64)

# %%
partition5 = class_majority_df
partition5=partition5.reset_index(drop=True)
partition5['cluster_label'] = fcm_labels
partition5
# Out:
#      Unnamed: 0  Preg   Plas   Pres  Skin   Insu  Mass   Pedi   Age  result  \
# 0           656   5.0   88.0   66.0  21.0   23.0  24.4  0.342  30.0       0
# 1           400   0.0  129.0   80.0   0.0    0.0  31.2  0.703  29.0       0
# 2           529   4.0  189.0  110.0  31.0    0.0  28.5  0.680  37.0       0
# 3           474   6.0   96.0    0.0   0.0    0.0  23.7  0.190  28.0       0
# 4            25   8.0   85.0   55.0  20.0    0.0  24.4  0.136  42.0       0
# ..          ...   ...    ...    ...   ...    ...   ...    ...   ...     ...
# 401         485   1.0  126.0   56.0  29.0  152.0  28.7  0.801  21.0       0
# 402         611   5.0  117.0   92.0   0.0    0.0  34.1  0.337  38.0       0
# 403         697   4.0  112.0   78.0  40.0    0.0  39.4  0.236  38.0       0
# 404         714   3.0   78.0   70.0   0.0    0.0  32.5  0.270  39.0       0
# 405         354   6.0  144.0   72.0  27.0  228.0  33.9  0.255  40.0       0
#
#      cluster_label
# 0                4
# 1                3
# 2                6
# 3                3
# 4                2
# ..             ...
# 401              1
# 402              6
# 403              4
# 404              4
# 405              0
#
# [406 rows x 11 columns]

# %%
partition1, partition2, partition3, partition4,partition5
# Out:
# (     Unnamed: 0  Preg   Plas   Pres  Skin   Insu  Mass   Pedi   Age  result  \
#  0           656   5.0   88.0   66.0  21.0   23.0  24.4  0.342  30.0       0
#  1           400   0.0  129.0   80.0   0.0    0.0  31.2  0.703  29.0       0
#  2           529   4.0  189.0  110.0  31.0    0.0  28.5  0.680  37.0       0
#  3           474   6.0   96.0    0.0   0.0    0.0  23.7  0.190  28.0       0
#  4            25   8.0   85.0   55.0  20.0    0.0  24.4  0.136  42.0       0
#  ..          ...   ...    ...    ...   ...    ...   ...    ...   ...     ...
#  401         485   1.0  126.0   56.0  29.0  152.0  28.7  0.801  21.0       0
#  402         611   5.0  117.0   92.0   0.0    0.0  34.1  0.337  38.0       0
#  403         697   4.0  112.0   78.0  40.0    0.0  39.4  0.236  38.0       0
#  404         714   3.0   78.0   70.0   0.0    0.0  32.5  0.270  39.0       0
#  405         354   6.0  144.0   72.0  27.0  228.0  33.9  0.255  40.0       0
#
#       cluster_label
#  0                6
#  1                3
#  2                3
#  3                3
#  4                0
#  ..             ...
#  401              4
#  402              6
#  403              6
#  404              6
#  405              5
#
#  [406 rows x 11 columns],
#       Unnamed: 0  Preg   Plas   Pres  Skin   Insu  Mass   Pedi   Age  result  \
#  0           656   5.0   88.0   66.0  21.0   23.0  24.4  0.342  30.0       0
#  1           400   0.0  129.0   80.0   0.0    0.0  31.2  0.703  29.0       0
#  2           529   4.0  189.0  110.0  31.0    0.0  28.5  0.680  37.0       0
#  3           474   6.0   96.0    0.0   0.0    0.0  23.7  0.190  28.0       0
#  4            25   8.0   85.0   55.0  20.0    0.0  24.4  0.136  42.0       0
#  ..          ...   ...    ...    ...   ...    ...   ...    ...   ...     ...
#  401         485   1.0  126.0   56.0  29.0  152.0  28.7  0.801  21.0       0
#  402         611   5.0  117.0   92.0   0.0    0.0  34.1  0.337  38.0       0
#  403         697   4.0  112.0   78.0  40.0    0.0  39.4  0.236  38.0       0
#  404         714   3.0   78.0   70.0   0.0    0.0  32.5  0.270  39.0       0
#  405         354   6.0  144.0   72.0  27.0  228.0  33.9  0.255  40.0       0
#
#       cluster_label
#  0                2
#  1                5
#  2                5
#  3                5
#  4                4
#  ..             ...
#  401              0
#  402              2
#  403              2
#  404              2
#  405              1
#
#  [406 rows x 11 columns],
#       Unnamed: 0  Preg   Plas   Pres  Skin   Insu  Mass   Pedi   Age  result  \
#  0           656   5.0   88.0   66.0  21.0   23.0  24.4  0.342  30.0       0
#  1           400   0.0  129.0   80.0   0.0    0.0  31.2  0.703  29.0       0
#  2           529   4.0  189.0  110.0  31.0    0.0  28.5  0.680  37.0       0
#  3           474   6.0   96.0    0.0   0.0    0.0  23.7  0.190  28.0       0
#  4            25   8.0   85.0   55.0  20.0    0.0  24.4  0.136  42.0       0
#  ..          ...   ...    ...    ...   ...    ...   ...    ...   ...     ...
#  401         485   1.0  126.0   56.0  29.0  152.0  28.7  0.801  21.0       0
#  402         611   5.0  117.0   92.0   0.0    0.0  34.1  0.337  38.0       0
#  403         697   4.0  112.0   78.0  40.0    0.0  39.4  0.236  38.0       0
#  404         714   3.0   78.0   70.0   0.0    0.0  32.5  0.270  39.0       0
#  405         354   6.0  144.0   72.0  27.0  228.0  33.9  0.255  40.0       0
#
#       cluster_label
#  0                0
#  1                1
#  2                0
#  3                0
#  4                6
#  ..             ...
#  401              3
#  402              0
#  403              0
#  404              0
#  405              0
#
#  [406 rows x 11 columns],
#       Unnamed: 0  Preg   Plas   Pres  Skin   Insu  Mass   Pedi   Age  result  \
#  0           656   5.0   88.0   66.0  21.0   23.0  24.4  0.342  30.0       0
#  1           400   0.0  129.0   80.0   0.0    0.0  31.2  0.703  29.0       0
#  2           529   4.0  189.0  110.0  31.0    0.0  28.5  0.680  37.0       0
#  3           474   6.0   96.0    0.0   0.0    0.0  23.7  0.190  28.0       0
#  4            25   8.0   85.0   55.0  20.0    0.0  24.4  0.136  42.0       0
#  ..          ...   ...    ...    ...   ...    ...   ...    ...   ...     ...
#  401         485   1.0  126.0   56.0  29.0  152.0  28.7  0.801  21.0       0
#  402         611   5.0  117.0   92.0   0.0    0.0  34.1  0.337  38.0       0
#  403         697   4.0  112.0   78.0  40.0    0.0  39.4  0.236  38.0       0
#  404         714   3.0   78.0   70.0   0.0    0.0  32.5  0.270  39.0       0
#  405         354   6.0  144.0   72.0  27.0  228.0  33.9  0.255  40.0       0
#
#       cluster_label
#  0                1
#  1                3
#  2                3
#  3                3
#  4                5
#  ..             ...
#  401              4
#  402              1
#  403              6
#  404              6
#  405              4
#
#  [406 rows x 11 columns],
#       Unnamed: 0  Preg   Plas   Pres  Skin   Insu  Mass   Pedi   Age  result  \
#  0           656   5.0   88.0   66.0  21.0   23.0  24.4  0.342  30.0       0
#  1           400   0.0  129.0   80.0   0.0    0.0  31.2  0.703  29.0       0
#  2           529   4.0  189.0  110.0  31.0    0.0  28.5  0.680  37.0       0
#  3           474   6.0   96.0    0.0   0.0    0.0  23.7  0.190  28.0       0
#  4            25   8.0   85.0   55.0  20.0    0.0  24.4  0.136  42.0       0
#  ..          ...   ...    ...    ...   ...    ...   ...    ...   ...     ...
#  401         485   1.0  126.0   56.0  29.0  152.0  28.7  0.801  21.0       0
#  402         611   5.0  117.0   92.0   0.0    0.0  34.1  0.337  38.0       0
#  403         697   4.0  112.0   78.0  40.0    0.0  39.4  0.236  38.0       0
#  404         714   3.0   78.0   70.0   0.0    0.0  32.5  0.270  39.0       0
#  405         354   6.0  144.0   72.0  27.0  228.0  33.9  0.255  40.0       0
#
#       cluster_label
#  0                4
#  1                3
#  2                6
#  3                3
#  4                2
#  ..             ...
#  401              1
#  402              6
#  403              4
#  404              4
#  405              0
#
#  [406 rows x 11 columns])

# %%
c = 0
for i in range(len(partition1.cluster_label)):
  print(partition1.cluster_label[i], partition2.cluster_label[i], partition3.cluster_label[i],partition4.cluster_label[i],partition5.cluster_label[i])
# Out:
# 6 2 0 1 4
# 3 5 1 3 3
# 3 5 0 3 6
# 3 5 0 3 3
# 0 4 6 5 2
# 6 2 5 1 4
# 4 0 0 4 1
# 3 5 6 3 3
# 6 2 0 1 6
# 1 3 4 0 5
# 4 0 0 4 1
# 3 5 2 3 3
# 1 3 2 0 5
# 0 4 1 5 2
# 3 5 0 3 3
# 6 2 1 1 4
# 1 3 1 0 0
# 6 2 3 6 4
# 6 2 5 6 4
# 1 3 4 0 3
# 0 4 0 5 2
# 1 3 0 0 3
# 4 0 1 3 1
# 6 2 5 1 6
# 0 4 0 5 2
# 0 4 0 5 2
# 1 3 1 0 5
# 1 3 4 0 0
# 6 2 1 1 4
# 0 4 0 5 5
# 0 4 5 5 2
# 6 2 3 1 4
# 3 5 0 3 6
# 1 3 1 0 5
# 3 5 1 3 3
# 6 2 3 1 6
# 5 1 0 0 0
# 1 3 1 0 0
# 0 4 0 5 5
# 6 2 3 1 4
# 6 2 1 6 4
# 6 2 4 1 4
# 0 4 1 5 2
# 0 4 2 5 2
# 6 2 0 1 6
# 0 4 1 5 5
# 6 2 0 6 4
# 4 0 0 4 1
# 0 4 2 5 2
# 3 5 2 3 6
# 2 2 0 6 4
# 6 2 2 6 4
# 6 2 0 6 4
# 3 5 2 3 3
# 3 5 5 3 3
# 6 2 6 1 4
# 2 6 0 4 1
# 6 2 3 6 4
# 0 4 1 5 2
# 1 3 4 0 5
# 6 2 1 6 4
# 6 2 0 1 6
# 4 0 3 4 1
# 2 0 3 4 1
# 1 3 5 0 5
# 6 2 3 6 4
# 5 1 0 2 0
# 1 3 2 0 3
# 1 3 4 0 0
# 4 0 3 4 1
# 6 2 6 6 4
# 3 5 2 3 3
# 3 5 0 3 3
# 5 1 1 2 0
# 1 3 3 0 0
# 1 3 1 0 0
# 0 4 0 5 5
# 4 0 3 4 1
# 3 5 0 3 6
# 0 4 0 5 2
# 0 4 6 5 5
# 0 4 0 5 2
# 5 1 5 2 0
# 1 3 1 0 5
# 1 3 5 0 5
# 3 5 2 3 3
# 6 2 2 1 6
# 3 5 0 3 3
# 4 5 3 3 3
# 3 5 0 3 3
# 1 3 0 0 5
# 5 1 3 2 0
# 0 4 0 5 2
# 2 6 6 4 1
# 1 3 0 0 0
# 4 0 3 4 1
# 1 3 1 0 0
# 1 3 6 0 5
# 2 6 1 4 1
# 1 3 6 0 5
# 3 5 0 3 3
# 3 5 0 3 3
# 1 3 5 0 5
# 4 0 0 4 1
# 0 4 3 5 2
# 0 4 5 5 2
# 3 5 0 3 3
# 6 2 2 1 6
# 6 2 1 1 6
# 0 4 4 5 2
# 1 3 2 0 5
# 3 5 0 3 3
# 4 0 3 1 6
# 1 3 0 0 5
# 2 6 1 4 1
# 1 3 3 0 5
# 6 2 2 6 4
# 4 0 2 4 1
# 5 1 0 0 0
# 3 5 1 3 3
# 0 4 2 5 2
# 4 5 1 3 3
# 0 4 0 5 5
# 6 2 1 6 4
# 0 4 4 5 2
# 0 4 5 5 2
# 6 2 6 1 6
# 1 3 2 0 5
# 3 5 0 3 3
# 3 5 0 3 6
# 6 2 5 1 6
# 1 3 3 0 0
# 6 2 1 6 4
# 0 4 1 5 2
# 1 3 1 0 5
# 6 2 4 6 4
# 4 0 1 4 0
# 6 2 5 6 4
# 0 4 1 5 2
# 3 5 3 3 3
# 1 3 2 0 5
# 6 2 4 6 4
# 4 0 0 4 1
# 4 0 0 4 1
# 6 2 2 6 4
# 2 0 1 4 1
# 1 3 0 0 3
# 6 2 4 1 6
# 1 3 6 0 3
# 6 2 0 1 6
# 0 4 3 5 2
# 4 5 1 3 3
# 1 3 1 0 0
# 1 3 6 0 5
# 1 3 1 0 3
# 0 4 2 5 2
# 1 3 0 0 3
# 3 5 0 3 3
# 4 0 0 4 1
# 5 1 3 0 0
# 0 4 6 5 2
# 3 5 0 3 3
# 6 2 0 1 6
# 6 2 0 1 6
# 3 5 2 3 3
# 6 2 3 1 4
# 0 4 0 5 5
# 2 6 6 4 1
# 6 2 5 6 4
# 1 3 2 0 0
# 1 3 2 0 3
# 0 4 0 5 2
# 4 0 2 4 1
# 6 2 3 6 4
# 6 2 0 6 4
# 3 2 6 1 6
# 0 4 0 5 2
# 1 3 2 0 5
# 6 2 2 1 6
# 4 0 0 1 6
# 1 3 0 0 5
# 1 3 3 0 5
# 3 5 1 3 3
# 0 4 0 5 2
# 0 4 0 5 2
# 6 2 2 6 4
# 0 4 0 5 2
# 6 2 5 1 6
# 4 0 0 4 1
# 0 4 0 5 2
# 1 3 3 0 0
# 1 3 2 0 3
# 4 0 0 3 1
# 3 5 1 3 6
# 0 4 1 5 5
# 0 4 0 5 2
# 6 2 0 1 6
# 1 3 4 0 3
# 1 3 4 0 5
# 1 3 0 0 5
# 3 5 4 3 3
# 4 0 5 0 0
# 5 1 0 2 0
# 1 3 6 0 5
# 0 4 0 5 2
# 6 2 0 1 6
# 0 4 5 5 2
# 6 2 0 1 6
# 3 5 0 3 3
# 6 2 6 6 4
# 4 0 0 0 3
# 0 4 2 5 2
# 0 4 0 5 2
# 3 5 2 3 6
# 6 2 3 6 4
# 6 2 0 6 4
# 6 2 2 6 4
# 1 3 0 0 5
# 5 1 0 2 0
# 6 2 0 6 4
# 1 3 5 0 5
# 6 2 1 1 6
# 0 4 3 5 5
# 3 5 3 3 6
# 1 3 4 0 0
# 0 4 0 5 2
# 0 4 0 5 2
# 4 0 3 3 3
# 4 0 6 3 1
# 1 3 2 0 5
# 6 2 0 1 6
# 2 6 3 4 1
# 4 0 5 4 1
# 4 0 0 4 1
# 1 3 0 0 0
# 4 5 0 3 6
# 0 4 5 5 2
# 3 5 0 3 3
# 1 3 0 0 5
# 3 5 2 3 6
# 4 0 5 4 1
# 3 5 5 3 6
# 2 6 0 4 1
# 6 2 6 1 6
# 3 5 0 3 3
# 1 3 1 0 3
# 6 2 2 6 4
# 3 5 1 3 3
# 0 4 1 5 2
# 3 5 4 3 3
# 5 1 1 4 0
# 5 1 2 2 2
# 1 3 0 0 5
# 0 4 0 5 2
# 5 1 0 2 2
# 0 4 1 5 2
# 0 4 2 5 2
# 1 3 0 0 3
# 1 3 0 0 5
# 6 2 0 1 6
# 0 4 3 5 2
# 0 4 1 5 2
# 0 4 0 5 2
# 0 4 3 5 2
# 0 4 4 5 5
# 6 2 1 6 4
# 6 2 1 6 4
# 1 3 0 0 5
# 0 4 3 5 2
# 0 4 0 5 2
# 1 3 1 0 0
# 6 2 5 1 4
# 6 2 0 6 4
# 6 2 4 6 4
# 0 4 0 5 2
# 1 3 0 0 5
# 1 3 0 0 5
# 0 4 1 5 2
# 6 2 0 6 4
# 0 4 0 5 2
# 2 6 3 4 1
# 0 4 0 5 2
# 5 1 3 2 2
# 6 2 1 1 6
# 6 2 3 6 4
# 4 5 3 0 3
# 1 3 4 0 5
# 3 5 5 3 6
# 4 0 1 1 1
# 6 2 3 6 4
# 1 3 2 0 0
# 5 1 1 2 0
# 6 2 3 1 6
# 6 2 3 6 4
# 3 5 5 3 6
# 6 2 0 6 4
# 1 3 2 0 5
# 2 0 0 4 1
# 1 3 0 0 5
# 5 1 3 2 0
# 3 5 4 3 3
# 0 4 2 5 2
# 4 0 0 3 6
# 3 5 0 3 6
# 0 4 3 5 2
# 3 5 2 3 3
# 4 0 1 1 1
# 6 2 0 1 4
# 4 0 0 3 0
# 6 2 2 6 4
# 0 4 0 5 2
# 0 4 1 5 2
# 0 4 0 5 2
# 3 5 1 3 3
# 1 3 0 0 0
# 0 4 4 5 5
# 0 4 5 5 2
# 0 4 3 5 2
# 4 0 3 1 1
# 1 3 0 0 5
# 1 3 5 0 3
# 3 5 5 3 3
# 3 5 1 3 6
# 4 0 0 3 6
# 3 5 3 3 6
# 6 2 1 6 4
# 6 2 1 1 4
# 0 4 4 5 2
# 3 5 0 3 3
# 6 2 3 6 4
# 0 4 5 5 2
# 5 1 1 2 0
# 1 3 0 0 5
# 0 4 3 5 2
# 3 5 0 3 6
# 1 3 0 0 5
# 2 0 1 4 1
# 0 4 3 5 2
# 3 5 0 3 3
# 6 2 0 6 4
# 3 5 1 3 3
# 6 2 2 6 4
# 1 3 1 0 3
# 5 1 6 0 0
# 3 5 6 3 3
# 1 3 0 0 5
# 4 0 0 4 1
# 5 1 5 2 0
# 6 2 0 1 4
# 6 2 0 1 6
# 6 2 2 1 6
# 6 2 0 1 6
# 0 4 0 5 2
# 1 3 0 0 5
# 4 0 2 4 1
# 6 2 3 1 6
# 3 5 3 3 3
# 6 2 0 1 4
# 4 0 2 4 1
# 1 3 1 0 0
# 5 1 3 2 0
# 6 2 3 6 4
# 1 3 2 0 5
# 0 4 5 5 5
# 1 3 1 0 5
# 6 2 6 6 4
# 1 3 2 0 3
# 4 0 1 4 1
# 6 2 0 6 4
# 3 5 0 3 3
# 2 0 4 4 1
# 1 3 0 0 5
# 3 5 0 3 6
# 0 4 0 5 2
# 0 4 0 5 2
# 5 1 0 4 0
# 5 1 0 2 0
# 3 5 2 1 6
# 1 3 1 0 5
# 4 0 0 3 3
# 5 1 1 2 0
# 2 2 0 6 4
# 1 3 6 0 3
# 6 2 2 1 6
# 1 3 2 0 3
# 1 3 0 0 5
# 6 2 3 1 6
# 0 4 2 5 2
# 3 5 0 3 3
# 5 1 0 2 2
# 3 5 4 3 6
# 3 5 1 3 3
# 4 0 4 0 3
# 5 1 1 2 2
# 1 3 2 0 5
# 0 4 1 5 2
# 5 1 1 2 0
# 5 1 6 2 0
# 3 5 5 1 6
# 1 3 0 0 0
# 0 4 6 5 5
# 4 0 3 4 1
# 6 2 0 1 6
# 6 2 0 6 4
# 6 2 0 6 4
# 5 1 0 4 0

# %% [markdown]
# **davies_bouldin_score**

# %%
from sklearn.metrics import davies_bouldin_score
print("Kmeans (partition 1): ",davies_bouldin_score(class_majority_df, partition1.cluster_label))
print("Kmeans++ (partition 2): ",davies_bouldin_score(class_majority_df, partition2.cluster_label))
print("KModes (partition 3): ",davies_bouldin_score(class_majority_df, partition3.cluster_label))
print("Minibatch Kmeans (partition 4): ",davies_bouldin_score(class_majority_df, partition4.cluster_label))
print("Fuzzy K-means(partition 5): ",davies_bouldin_score(class_majority_df, partition5.cluster_label))
# Out:
# Kmeans (partition 1):  0.9104325248306208
# Kmeans++ (partition 2):  0.88476892552449
# KModes (partition 3):  19.60102075876482
# Minibatch Kmeans (partition 4):  0.9571593709881346
# Fuzzy K-means(partition 5):  0.9747961471463122

# %%
partitionA, partitionB, partitionC = partition1, partition2, partition4

# %%
partitionA, partitionB, partitionC = partition1, partition2, partition4
class_majority = class_majority_df
class_majority['C1'] = partitionA.cluster_label.values
class_majority['C2'] = partitionB.cluster_label.values
class_majority['C3'] = partitionC.cluster_label.values
class_majority.to_csv("DataSets/modified_majority_class.csv")
class_majority
# Out:
#      Unnamed: 0  Preg   Plas   Pres  Skin   Insu  Mass   Pedi   Age  result  \
# 0           656   5.0   88.0   66.0  21.0   23.0  24.4  0.342  30.0       0
# 1           400   0.0  129.0   80.0   0.0    0.0  31.2  0.703  29.0       0
# 2           529   4.0  189.0  110.0  31.0    0.0  28.5  0.680  37.0       0
# 3           474   6.0   96.0    0.0   0.0    0.0  23.7  0.190  28.0       0
# 4            25   8.0   85.0   55.0  20.0    0.0  24.4  0.136  42.0       0
# ..          ...   ...    ...    ...   ...    ...   ...    ...   ...     ...
# 401         485   1.0  126.0   56.0  29.0  152.0  28.7  0.801  21.0       0
# 402         611   5.0  117.0   92.0   0.0    0.0  34.1  0.337  38.0       0
# 403         697   4.0  112.0   78.0  40.0    0.0  39.4  0.236  38.0       0
# 404         714   3.0   78.0   70.0   0.0    0.0  32.5  0.270  39.0       0
# 405         354   6.0  144.0   72.0  27.0  228.0  33.9  0.255  40.0       0
#
#      C1  C2  C3
# 0     6   2   1
# 1     3   5   3
# 2     3   5   3
# 3     3   5   3
# 4     0   4   5
# ..   ..  ..  ..
# 401   4   0   4
# 402   6   2   1
# 403   6   2   6
# 404   6   2   6
# 405   5   1   4
#
# [406 rows x 13 columns]
